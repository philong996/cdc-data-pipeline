# %%
# %load_ext autoreload
# %autoreload 2

import sys

sys.path.append("..")

# %%
# Configure logging to see logs in notebook
import logging
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(name)s - %(levelname)s - %(message)s',
    handlers=[logging.StreamHandler()],
    force=True
)

# %%
from cdc_pipelines.common.logger import get_logger
from cdc_pipelines.pipelines.gold.gold_pipeline import GoldPipeline


from cdc_pipelines.pipelines.gold.jobs import (
    build_product_performance_daily,
    build_customer_order_summary,
    build_order_hourly_patterns
)

# %%
config = "../config/pipeline_config/"
env = "prod"

pipeline = GoldPipeline(config, environment=env)
# Out:
# 2025-12-29 13:19:03,836 - cdc_pipelines.pipelines.gold.gold_pipeline - INFO - [GOLD] Starting gold layer pipeline
# 2025-12-29 13:19:03,838 - cdc_pipelines.common.spark_session - INFO - Creating new Spark session
# WARNING: Using incubator modules: jdk.incubator.vector
# :: loading settings :: url = jar:file:/home/longnguyen/miniconda3/envs/spark_env/lib/python3.10/site-packages/pyspark/jars/ivy-2.5.3.jar!/org/apache/ivy/core/settings/ivysettings.xml
# Ivy Default Cache set to: /home/longnguyen/.ivy2.5.2/cache
# The jars for the packages stored in: /home/longnguyen/.ivy2.5.2/jars
# org.apache.spark#spark-sql-kafka-0-10_2.13 added as a dependency
# io.delta#delta-spark_2.13 added as a dependency
# com.google.cloud.bigdataoss#gcs-connector added as a dependency
# :: resolving dependencies :: org.apache.spark#spark-submit-parent-9739ee1b-d900-488c-a64e-1e57fb92c8d7;1.0
# 	confs: [default]
# 	found org.apache.spark#spark-sql-kafka-0-10_2.13;4.0.0 in central
# ...

# %%
build_product_performance_daily(pipeline.spark, pipeline.config)
# Out:
# 2025-12-28 23:26:52,797 - cdc_pipelines.pipelines.gold.jobs.product_performance_daily - INFO - Building product_performance_daily table
# 2025-12-28 23:26:52,799 - cdc_pipelines.pipelines.gold.silver_reader - INFO - Initialized SilverReader
# 2025-12-28 23:26:52,800 - cdc_pipelines.pipelines.gold.silver_reader - INFO - Reading current dimension records from: products
# 2025-12-28 23:26:52,801 - cdc_pipelines.pipelines.gold.silver_reader - INFO - Reading silver table: products from gs://cdc-pipeline-data/prod/silver/products
# 25/12/28 23:26:59 WARN SparkStringUtils: Truncated the string representation of a plan since it was too large. This behavior can be adjusted by setting 'spark.sql.debug.maxToStringFields'.
# 2025-12-28 23:27:25,581 - cdc_pipelines.pipelines.gold.silver_reader - INFO - Read 49688 records from products
# 2025-12-28 23:27:33,159 - cdc_pipelines.pipelines.gold.silver_reader - INFO - Found 49688 current records in products
# ...

# %%
build_customer_order_summary(pipeline.spark, pipeline.config)
# Out:
# 2025-12-29 13:19:53,799 - cdc_pipelines.pipelines.gold.jobs.customer_order_summary - INFO - Building customer_order_summary table
# 2025-12-29 13:19:53,800 - cdc_pipelines.pipelines.gold.silver_reader - INFO - Initialized SilverReader
# 2025-12-29 13:19:53,802 - cdc_pipelines.pipelines.gold.silver_reader - INFO - Reading fact table: orders
# 2025-12-29 13:19:53,803 - cdc_pipelines.pipelines.gold.silver_reader - INFO - Reading silver table: orders from gs://cdc-pipeline-data/prod/silver/orders
# 25/12/29 13:20:00 WARN SparkStringUtils: Truncated the string representation of a plan since it was too large. This behavior can be adjusted by setting 'spark.sql.debug.maxToStringFields'.
# 2025-12-29 13:20:17,292 - cdc_pipelines.pipelines.gold.silver_reader - INFO - Read 62974 records from orders
# 2025-12-29 13:20:23,922 - cdc_pipelines.pipelines.gold.silver_reader - INFO - Filtered to 62974 non-deleted records in orders
# ...

# %%
build_order_hourly_patterns(pipeline.spark, pipeline.config)
# Out:
# 2025-12-29 13:29:48,497 - cdc_pipelines.pipelines.gold.jobs.order_hourly_patterns - INFO - Building order_hourly_patterns table
# 2025-12-29 13:29:48,499 - cdc_pipelines.pipelines.gold.silver_reader - INFO - Initialized SilverReader
# 2025-12-29 13:29:48,499 - cdc_pipelines.pipelines.gold.silver_reader - INFO - Reading fact table: orders
# 2025-12-29 13:29:48,500 - cdc_pipelines.pipelines.gold.silver_reader - INFO - Reading silver table: orders from gs://cdc-pipeline-data/prod/silver/orders
# 2025-12-29 13:29:49,485 - cdc_pipelines.pipelines.gold.silver_reader - INFO - Read 62974 records from orders
# 2025-12-29 13:29:51,042 - cdc_pipelines.pipelines.gold.silver_reader - INFO - Filtered to 62974 non-deleted records in orders
# 2025-12-29 13:29:51,044 - cdc_pipelines.pipelines.gold.silver_reader - INFO - Reading fact table: order_products
# ...
